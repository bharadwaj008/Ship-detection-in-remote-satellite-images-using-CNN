# %% [markdown]
# # Detection using Faster CNN
#
# This notebook contains a process of creating an end to end Faster R-CNN model using tensorflow. First features are extracted from the images using a CNN model and then passed through a Region Proposal Network(RPN). All due credit for the algorithm goes to the authors of the paper, *Faster R-CNN: Towards Real-Time Object
# Detection with Region Proposal Networks*.

# %% [markdown]
# # Importing libraries
#
# The necessary libraries required for implementing the Faster R-CNN model are imported in the code block below.

# %%
from keras.engine.base_layer import Layer
from keras.layers import Activation, Dense
from keras import backend as K
from sklearn.model_selection import train_test_split
from keras.datasets import mnist
from tensorflow.keras.optimizers import SGD
from keras.utils import np_utils

import keras
from keras.models import Sequential
from keras.layers.core import Flatten
from keras.layers import Dropout
from keras.layers import Conv2D, MaxPooling2D
#import tensorflow.keras.layers.BatchNormalization
import numpy as np

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, random, cv2, pickle, json, itertools
import imgaug.augmenters as iaa
import imgaug.imgaug

from IPython.display import SVG
from tensorflow.keras.utils import plot_model, model_to_dot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.utils import class_weight
from tqdm import tqdm
from sklearn.preprocessing import LabelBinarizer

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Add, Input, Conv2D, Dropout, Activation, BatchNormalization, MaxPooling2D, ZeroPadding2D, AveragePooling2D, Flatten, Dense)
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import *
import tensorflow as tf

# %% [markdown]
# # Utility functions
#
# * show_final_history - For plotting the loss and accuracy of the training and validation datasets
# * plot_confusion_matrix - For plotting the percentage of true positives per class for a better feel of how the model predicted the data

# %%
def show_final_history(history):
    
    plt.style.use("ggplot")
    fig, ax = plt.subplots(1,2,figsize=(15,5))
    ax[0].set_title('Loss')
    ax[1].set_title('Accuracy')
    ax[0].plot(history.history['loss'],label='Train Loss')
    ax[0].plot(history.history['val_loss'],label='Validation Loss')
    ax[1].plot(history.history['accuracy'],label='Train Accuracy')
    ax[1].plot(history.history['val_accuracy'],label='Validation Accuracy')
    
    ax[0].legend(loc='upper right')
    ax[1].legend(loc='lower right')
    plt.show();
    pass

# %%
def plot_confusion_matrix(cm,classes,title='Confusion Matrix',cmap=plt.cm.Blues):
    
#     np.seterr(divide='ignore',invalid='ignore')
    cm = cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm,interpolation='nearest',cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes,rotation=45)
    plt.yticks(tick_marks, classes)
    
    fmt = '.2f'
    thresh = cm.max()/2.
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,format(cm[i,j],fmt),
                horizontalalignment="center",
                color="white" if cm[i,j] > thresh else "black")
        pass
    
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    pass

# %% [markdown]
# # Uploading the images
#
# The images from the **satellite-imagery-of-ships** is loaded into numpy arrays, with labels [0,1] corresponding to the classes *no-ship* and *ship*. The data was loaded into numpy arrays as data augmentation and upsampling/downsampling is easier to perform.

# %%
datasets = ['../input/satellite-imagery-of-ships']

class_names = ["no-ship","ship"]

class_name_labels = {class_name:i for i,class_name in enumerate(class_names)}

num_classes = len(class_names)
class_name_labels
# Out:
# {'no-ship': 0, 'ship': 1}

# %% [markdown]
# OpenCV uses BGR image format. So, when we read an image using cv2.imread() it interprets in BGR format by default.
#
# We can use cvtColor() method to convert a BGR image to RGB and vice-versa.

# %%
def load_data():
    images, labels = [], []
    
    for dataset in datasets:
        
        for folder in os.listdir(dataset):
            label = class_name_labels[folder]
            
            for file in tqdm(os.listdir(os.path.join(dataset,folder))):
                
                img_path = os.path.join(dataset,folder,file)
                
                img = cv2.imread(img_path)
                img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (64,64))
                
                images.append(img)
                labels.append(label)
                pass
            pass
        
        images = np.array(images,dtype=np.float32)/255.0
        labels = np.array(labels,dtype=np.float32)
        pass
    
    return (images, labels)
    pass

# %%
(images, labels) = load_data()
images.shape, labels.shape
# Out:
# 100%|██████████| 1000/1000 [00:08<00:00, 121.36it/s]
# 100%|██████████| 3000/3000 [00:25<00:00, 118.58it/s]
# ((4000, 64, 64, 3), (4000,))

# %% [markdown]
# # EDA of dataset
#
# * bar-plot - Bar plot is made to find the count of images per class
# * pie-plot - Pie plot is drawn to find the percentage of class distribution in the dataset

# %%
n_labels = labels.shape[0]

_, count = np.unique(labels, return_counts=True)

df = pd.DataFrame(data = count)
df['Class Label'] = class_names
df.columns = ['Count','Class-Label']
df.set_index('Class-Label',inplace=True)
df
# Out:
#              Count
# Class-Label
# no-ship       3000
# ship          1000

# %%
df.plot.bar(rot=0)
plt.title("distribution of images per class");

# %% [markdown]
# As it can be seen that the data is skewed towards the *no-ship* class with 75% of images belonging to that very specific class.

# %%
plt.pie(count,
       explode=(0,0),
       labels=class_names,
       autopct="%1.2f%%")
plt.axis('equal');

# %% [markdown]
# Due to imbalance in dataset, upsampling is done on the minority class, by randomly duplicating images until the 2 classes have comparable distribution in the dataset. After this is done, the dataset will be split into the training, testing and validation sets by randomly shuffling them and then splitting.
#
# Another way is to introduce class weights for each specific class. Each class is penalised with the specific class weight. Higher the class weight, greater the penalty. Classes with lower percentage have a higher penalty. This allows for the model to penalise itself heavily if class detected is incorrect.

# %% [markdown]
# # Augmenting Images of Minority Class
#
# The images present in the *ship* class are augmented and then stored in the dataset, so that there is an equal representation of the classes. The current ratio of classes is 1:3, meaning that for every image present in the *ship* class there are 3 images present in the *no-ship* class. This will be countered by producing 2 augmented images per original image of the *ship* class. This will make the dataset balanced.

# %% [markdown]
# If augmentation of dataset is required then set AUGMENTATION to *True*. This will balance the dataset via augmentation of minority classes. To train via class weights, then set AUGMENTATION to *False*.

# %%
AUGMENTATION = True

# %%
def augment_add(images, seq, labels):
    
    augmented_images, augmented_labels = [],[]
    for idx,img in tqdm(enumerate(images)):
        
        if labels[idx] == 1:
            image_aug_1 = seq.augment_image(image=img)
            image_aug_2 = seq.augment_image(image=img)
            augmented_images.append(image_aug_1)
            augmented_images.append(image_aug_2)
            augmented_labels.append(labels[idx])
            augmented_labels.append(labels[idx])
        pass
    
    augmented_images = np.array(augmented_images, dtype=np.float32)
    augmented_labels = np.array(augmented_labels, dtype=np.float32)
    
    return (augmented_images, augmented_labels)
    pass

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Crop(percent=(0,0.1)),
    iaa.LinearContrast((0.75,1.5)),
    iaa.Multiply((0.8,1.2), per_channel=0.2),
    iaa.Affine(
        scale={'x':(0.8,1.2), "y":(0.8,1.2)},
        translate_percent={"x":(-0.2,0.2),"y":(-0.2,0.2)},
        rotate=(-25,25),
        shear=(-8,8)
    )
], random_order=True)

# %%
if AUGMENTATION:
    (aug_images, aug_labels) = augment_add(images, seq, labels)
    images = np.concatenate([images, aug_images])
    labels = np.concatenate([labels, aug_labels])
# Out:
# 4000it [00:05, 758.46it/s]

# %%
images.shape, labels.shape
# Out:
# ((6000, 64, 64, 3), (6000,))

# %%
if AUGMENTATION:
    _, count = np.unique(labels, return_counts=True)

    plt.pie(count,
           explode=(0,0),
           labels=class_names,
           autopct="%1.2f%%")
    plt.axis('equal');

# %% [markdown]
# # One Hot Encoding Variables
#
# The labels numpy array is one hot encoded using *to_categorical* from keras. This removes any uncessary bias in the dataset, by keeping the class at equal footing, with respect to labels.

# %%
labels = to_categorical(labels)

# %% [markdown]
# # Training, Validation and Testing
#
# Instead of using *train_test_split* the images and labels arrays are randomly shuffled using the same seed value set at *42*. This allows the images and their corresponding labels to remain linked even after shuffling.
#
# This method allows the user to make all 3 datasets. The training and validation dataset is used for training the model while the testing dataset is used for testing the model on unseen data. Unseen data is used for simulating real-world prediction, as the model has not seen this data before. It allows the developers to see how robust the model is.

# %%
np.random.seed(42)
np.random.shuffle(images)

np.random.seed(42)
np.random.shuffle(labels)

# %% [markdown]
# ## Spliting of data
#
# * 70% - Training
# * 20% - Validation
# * 10% - Testing

# %%
total_count = len(images)
total_count

train = int(0.7*total_count)
val = int(0.2*total_count)
test = int(0.1*total_count)

train_images, train_labels = images[:train], labels[:train]
val_images, val_labels = images[train:(val+train)], labels[train:(val+train)]
test_images, test_labels = images[-test:], labels[-test:]

train_images.shape, val_images.shape, test_images.shape
# Out:
# ((4200, 64, 64, 3), (1200, 64, 64, 3), (600, 64, 64, 3))

# %% [markdown]
# If AUGMENTATION is set True, then the number of images per class is balanced. If AUGMENTATION is set to False, then compute the class weights given below and accordingly change the fit function of the Keras API when training.

# %%
if not AUGMENTATION:
    count_labels = train_labels.sum(axis=0)

    classTotals = train_labels.sum(axis=0)
    classWeight = {}

    for i in range(0,len(classTotals)):
        classWeight[i] = classTotals.max()/classTotals[i]
        pass
    print(classWeight)

# %% [markdown]
# # Creation of model
#
# * **conv_block** - This function contains the convulotional layer, batch normalization and activation layers. The number of filters, kernel_size, strides to be taken are defined by the developer. This allows a developer to make the model without having to repeat the same lines continuously many times. It also uses the OOPs concepts of Python which is recommended instead of coding like it is *C*.
#
# * **basic_model** - This function creates the model using the aforementioned function, max pooling layers and dropouts. After the specified number of convolutional layers, a flatten layer is introduced, along with dense layers so that the image can be classified. The flatten layer converts the feature map produced by the convolutional layers into a single column for classification.
#
# For image detection in images using Faster R-CNN the feature map produced by the convolutional layers is used, i.e., the model drops the layers after the final convolutional block and passes the generated feature map to a Regional Proposal Network, which can either uses a vanilla CNN model containing fully connected layers or a Logistic Regression, Support Vector machines or Random forests. Advised to use vanilla CNN as it uses less CPU and memory, plus slightly faster and capable of giving multiple outputs if required.

# %% [markdown]
# ## Explanation of features
#
# * Conv2D - This is a 2 dimensional convolutional layer, the number of filters decide what the convolutional layer learns. Greater the number of filters, greater the amount of information obtained.
#
# ![Conv2D Visualisation](https://www.pyimagesearch.com/wp-content/uploads/2018/12/keras_conv2d_num_filters.png)
#
# * MaxPooling2D - This reduces the spatial dimensions of the feature map produced by the convolutional layer without losing any range information. This allows a model to become slightly more robust
# * Dropout - This removes a user-defined percentage of links between neurons of consecutive layers. This allows the model to be robust. It can be used in both fully convolutional layers and fully connected layers.
# * BatchNormalization - This layer normalises the values present in the hidden part of the neural network. This is similar to MinMax/Standard scaling applied in machine learning algorithms
# * Padding- This pads the feature map/input image with zeros allowing border features to stay.

# %%
class gcu(Layer):
    def __init__(self, **kwargs):
        super(gcu, self).__init__(**kwargs)
        self.supports_masking = True

    def call(self, inputs):
        return inputs * math.cos(inputs)

    def get_config(self):
        base_config = super(gcu, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

    def compute_output_shape(self, input_shape):
        return input_shape

# %%
def gcu(x):
  return x*tf.cos(x)

tf.keras.utils.get_custom_objects().update({'gcu': Activation(gcu)})

# %%
def conv_block(X,k,filters,stage,block,s=2):
    
    conv_base_name = 'conv_' + str(stage)+block+'_branch'
    bn_base_name = 'bn_'+str(stage)+block+"_branch"
    
    F1 = filters
    
    X = Conv2D(filters=F1, kernel_size=(k,k), strides=(s,s),
              padding='same',name=conv_base_name+'2a')(X)
    X = Activation('relu')(X)
    X = BatchNormalization(name=bn_base_name+'2a')(X)
    
    
    return X
    pass

# %% [markdown]
# ## Creation of Model
#
# ### Block 1
# * An input layer is initialised using the Input Keras layer, this defines the number of neurons present in the input layer
# * ZeroPadding is applied to the input image, so that boundary features are not lost.
#
# ### Block 2
# * First Convolutioanl Layer, it starts with 16 filters and kernel size with (3,3) and strides (2,2). Padding is maintaned same, so the image does not chaneg spatially, until the next block in which MaxPooling occurs
#
# ### Block 3 - 4
# * Similar structure in both with a convolutional layer followed by a MaxPooling and Dropout layers.
#
# ### Output Block
# * The feature map produced by the previous convolutional layers is converted into a single column using Flatten Layer and the classified using a Dense layer(output layer) with the number of classes present in the dataset, and *sigmoid* as activation function.

# %%
def basic_model(input_shape,classes):
    
    X_input = Input(input_shape)
    
    X = ZeroPadding2D((5,5))(X_input)
    
    X = Conv2D(16,(3,3),strides=(2,2),name='conv1',padding="same")(X)
    X = BatchNormalization(name='bn_conv1')(X)
    
    # stage 2
    X = conv_block(X,3,32,2,block='A',s=1)
    X = MaxPooling2D((2,2))(X)
    X = Dropout(0.25)(X)

#     Stage 3
    X = conv_block(X,5,32,3,block='A',s=2)
    X = MaxPooling2D((2,2))(X)
    X = Dropout(0.25)(X)
    
#     Stage 4
    X = conv_block(X,3,64,4,block='A',s=1)
    X = MaxPooling2D((2,2))(X)
    X = Dropout(0.25)(X)
    
#   Output Layer
    X = Flatten()(X)
    X = Dense(64)(X)
    X = Dropout(0.5)(X)
    
    X = Dense(128)(X)
    X = Activation("relu")(X)
    
    X = Dense(classes,activation="softmax",name="fc"+str(classes))(X)
    
    model = Model(inputs=X_input,outputs=X,name='Feature_Extraction_and_FC')
    
    return model
    pass

# %%
model = basic_model(input_shape=(64,64,3),classes=2)

# %%
plot_model(model,to_file='basic_model.png')
SVG(model_to_dot(model).create(prog='dot',format='svg'))

model.summary()
# Out:
# Model: "Feature_Extraction_and_FC"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 74, 74, 3)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 37, 37, 16)        448
# _________________________________________________________________
# bn_conv1 (BatchNormalization (None, 37, 37, 16)        64
# _________________________________________________________________
# conv_2A_branch2a (Conv2D)    (None, 37, 37, 32)        4640
# _________________________________________________________________
# activation_9 (Activation)    (None, 37, 37, 32)        0
# _________________________________________________________________
# bn_2A_branch2a (BatchNormali (None, 37, 37, 32)        128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 18, 18, 32)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 18, 18, 32)        0
# _________________________________________________________________
# conv_3A_branch2a (Conv2D)    (None, 9, 9, 32)          25632
# _________________________________________________________________
# activation_10 (Activation)   (None, 9, 9, 32)          0
# _________________________________________________________________
# bn_3A_branch2a (BatchNormali (None, 9, 9, 32)          128
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 4, 4, 32)          0
# _________________________________________________________________
# conv_4A_branch2a (Conv2D)    (None, 4, 4, 64)          18496
# _________________________________________________________________
# activation_11 (Activation)   (None, 4, 4, 64)          0
# _________________________________________________________________
# bn_4A_branch2a (BatchNormali (None, 4, 4, 64)          256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               8320
# _________________________________________________________________
# activation_12 (Activation)   (None, 128)               0
# _________________________________________________________________
# fc2 (Dense)                  (None, 2)                 258
# =================================================================
# Total params: 74,818
# Trainable params: 74,530
# Non-trainable params: 288
# _________________________________________________________________

# %% [markdown]
# ## Compiling the Model
#
# The model is compiled using the *Adam* optimizer with learning rate set at 1e-3. *Binary Crossentropy* is used as a loss function as there are only two classes.

# %%
opt = Adam(lr=5e-4)
model.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint("model_weights.h5",monitor='val_accuracy',verbose=1,save_best_only=True,mode='max')
logs = TensorBoard("logs")

# %% [markdown]
# # Training model
#
# The model is trained for 50 epochs with a batch size of 16. The best model weights are stored in the file *model_weight.h5* with TensorBoard logs being stored in the *logs* directory.

# %%
epochs = 50
batch_size = 16

history = model.fit(train_images,train_labels,
                   steps_per_epoch=len(train_images)//batch_size,
                   epochs=epochs,
                   verbose=1, 
                   validation_data=(val_images,val_labels),
                   validation_steps=len(val_images)//batch_size,
                   callbacks=[checkpoint, logs]
#                    class_weight=classWeight # Uncomment if AUGMENTATION is set to FALSE
                   )
# Out:
# Epoch 1/50
# 260/262 [============================>.] - ETA: 0s - loss: 0.5817 - accuracy: 0.7434
# Epoch 00001: val_accuracy improved from -inf to 0.71500, saving model to model_weights.h5
# 262/262 [==============================] - 2s 7ms/step - loss: 0.5791 - accuracy: 0.7443 - val_loss: 0.5412 - val_accuracy: 0.7150
# Epoch 2/50
# 256/262 [============================>.] - ETA: 0s - loss: 0.2985 - accuracy: 0.8842
# Epoch 00002: val_accuracy improved from 0.71500 to 0.92917, saving model to model_weights.h5
# 262/262 [==============================] - 1s 5ms/step - loss: 0.2964 - accuracy: 0.8851 - val_loss: 0.1806 - val_accuracy: 0.9292
# Epoch 3/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.2242 - accuracy: 0.9083
# Epoch 00003: val_accuracy did not improve from 0.92917
# 262/262 [==============================] - 1s 4ms/step - loss: 0.2217 - accuracy: 0.9101 - val_loss: 0.2326 - val_accuracy: 0.9017
# Epoch 4/50
# 254/262 [============================>.] - ETA: 0s - loss: 0.1905 - accuracy: 0.9242
# Epoch 00004: val_accuracy improved from 0.92917 to 0.93417, saving model to model_weights.h5
# 262/262 [==============================] - 1s 4ms/step - loss: 0.1888 - accuracy: 0.9247 - val_loss: 0.1556 - val_accuracy: 0.9342
# Epoch 5/50
# 258/262 [============================>.] - ETA: 0s - loss: 0.1340 - accuracy: 0.9478
# Epoch 00005: val_accuracy improved from 0.93417 to 0.96417, saving model to model_weights.h5
# 262/262 [==============================] - 1s 4ms/step - loss: 0.1341 - accuracy: 0.9475 - val_loss: 0.1013 - val_accuracy: 0.9642
# Epoch 6/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.1117 - accuracy: 0.9581
# Epoch 00006: val_accuracy improved from 0.96417 to 0.97250, saving model to model_weights.h5
# 262/262 [==============================] - 1s 5ms/step - loss: 0.1112 - accuracy: 0.9576 - val_loss: 0.0728 - val_accuracy: 0.9725
# Epoch 7/50
# 255/262 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9532
# Epoch 00007: val_accuracy did not improve from 0.97250
# 262/262 [==============================] - 1s 4ms/step - loss: 0.1175 - accuracy: 0.9534 - val_loss: 0.0724 - val_accuracy: 0.9725
# Epoch 8/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0910 - accuracy: 0.9647
# Epoch 00008: val_accuracy improved from 0.97250 to 0.97500, saving model to model_weights.h5
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0909 - accuracy: 0.9646 - val_loss: 0.0715 - val_accuracy: 0.9750
# Epoch 9/50
# 251/262 [===========================>..] - ETA: 0s - loss: 0.0837 - accuracy: 0.9694
# Epoch 00009: val_accuracy improved from 0.97500 to 0.97667, saving model to model_weights.h5
# 262/262 [==============================] - 1s 5ms/step - loss: 0.0829 - accuracy: 0.9694 - val_loss: 0.0606 - val_accuracy: 0.9767
# Epoch 10/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.0746 - accuracy: 0.9780
# Epoch 00010: val_accuracy did not improve from 0.97667
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0757 - accuracy: 0.9777 - val_loss: 0.1390 - val_accuracy: 0.9433
# Epoch 11/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0715 - accuracy: 0.9753
# Epoch 00011: val_accuracy improved from 0.97667 to 0.98000, saving model to model_weights.h5
# 262/262 [==============================] - 1s 5ms/step - loss: 0.0745 - accuracy: 0.9741 - val_loss: 0.0570 - val_accuracy: 0.9800
# Epoch 12/50
# 251/262 [===========================>..] - ETA: 0s - loss: 0.0774 - accuracy: 0.9704
# Epoch 00012: val_accuracy improved from 0.98000 to 0.98583, saving model to model_weights.h5
# 262/262 [==============================] - 1s 5ms/step - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0435 - val_accuracy: 0.9858
# Epoch 13/50
# 260/262 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9791
# Epoch 00013: val_accuracy did not improve from 0.98583
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0545 - accuracy: 0.9790 - val_loss: 0.0564 - val_accuracy: 0.9800
# Epoch 14/50
# 249/262 [===========================>..] - ETA: 0s - loss: 0.0485 - accuracy: 0.9808
# Epoch 00014: val_accuracy did not improve from 0.98583
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0495 - accuracy: 0.9802 - val_loss: 0.0592 - val_accuracy: 0.9825
# Epoch 15/50
# 249/262 [===========================>..] - ETA: 0s - loss: 0.0586 - accuracy: 0.9801
# Epoch 00015: val_accuracy did not improve from 0.98583
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0570 - accuracy: 0.9804 - val_loss: 0.0450 - val_accuracy: 0.9800
# Epoch 16/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0512 - accuracy: 0.9839
# Epoch 00016: val_accuracy did not improve from 0.98583
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0505 - accuracy: 0.9842 - val_loss: 0.2334 - val_accuracy: 0.9433
# Epoch 17/50
# 251/262 [===========================>..] - ETA: 0s - loss: 0.0431 - accuracy: 0.9835
# Epoch 00017: val_accuracy did not improve from 0.98583
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0431 - accuracy: 0.9838 - val_loss: 0.0438 - val_accuracy: 0.9842
# Epoch 18/50
# 258/262 [============================>.] - ETA: 0s - loss: 0.0413 - accuracy: 0.9844
# Epoch 00018: val_accuracy did not improve from 0.98583
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0409 - accuracy: 0.9846 - val_loss: 0.1571 - val_accuracy: 0.9550
# Epoch 19/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0355 - accuracy: 0.9879
# Epoch 00019: val_accuracy did not improve from 0.98583
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0361 - accuracy: 0.9876 - val_loss: 0.0625 - val_accuracy: 0.9792
# Epoch 20/50
# 251/262 [===========================>..] - ETA: 0s - loss: 0.0288 - accuracy: 0.9911
# Epoch 00020: val_accuracy did not improve from 0.98583
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0285 - accuracy: 0.9912 - val_loss: 0.1135 - val_accuracy: 0.9725
# Epoch 21/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0346 - accuracy: 0.9879
# Epoch 00021: val_accuracy did not improve from 0.98583
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0339 - accuracy: 0.9881 - val_loss: 0.1175 - val_accuracy: 0.9692
# Epoch 22/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.0377 - accuracy: 0.9864
# Epoch 00022: val_accuracy improved from 0.98583 to 0.98667, saving model to model_weights.h5
# 262/262 [==============================] - 1s 5ms/step - loss: 0.0370 - accuracy: 0.9865 - val_loss: 0.0377 - val_accuracy: 0.9867
# Epoch 23/50
# 259/262 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9900
# Epoch 00023: val_accuracy did not improve from 0.98667
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0385 - accuracy: 0.9899 - val_loss: 0.0603 - val_accuracy: 0.9792
# Epoch 24/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0480 - accuracy: 0.9851
# Epoch 00024: val_accuracy did not improve from 0.98667
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0469 - accuracy: 0.9854 - val_loss: 0.0441 - val_accuracy: 0.9850
# Epoch 25/50
# 254/262 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9863
# Epoch 00025: val_accuracy improved from 0.98667 to 0.98750, saving model to model_weights.h5
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0381 - accuracy: 0.9854 - val_loss: 0.0372 - val_accuracy: 0.9875
# Epoch 26/50
# 254/262 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9874
# Epoch 00026: val_accuracy improved from 0.98750 to 0.99333, saving model to model_weights.h5
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0365 - accuracy: 0.9876 - val_loss: 0.0318 - val_accuracy: 0.9933
# Epoch 27/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.0259 - accuracy: 0.9916
# Epoch 00027: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0254 - accuracy: 0.9919 - val_loss: 0.0437 - val_accuracy: 0.9892
# Epoch 28/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.0214 - accuracy: 0.9925
# Epoch 00028: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 5ms/step - loss: 0.0218 - accuracy: 0.9923 - val_loss: 0.0390 - val_accuracy: 0.9850
# Epoch 29/50
# 255/262 [============================>.] - ETA: 0s - loss: 0.0478 - accuracy: 0.9829
# Epoch 00029: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0477 - accuracy: 0.9826 - val_loss: 0.0882 - val_accuracy: 0.9783
# Epoch 30/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0315 - accuracy: 0.9897
# Epoch 00030: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.0582 - val_accuracy: 0.9842
# Epoch 31/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.0294 - accuracy: 0.9904
# Epoch 00031: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0284 - accuracy: 0.9908 - val_loss: 0.0389 - val_accuracy: 0.9875
# Epoch 32/50
# 258/262 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9876
# Epoch 00032: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0323 - accuracy: 0.9876 - val_loss: 0.0322 - val_accuracy: 0.9875
# Epoch 33/50
# 254/262 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9947
# Epoch 00033: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0137 - accuracy: 0.9946 - val_loss: 0.0330 - val_accuracy: 0.9875
# Epoch 34/50
# 251/262 [===========================>..] - ETA: 0s - loss: 0.0199 - accuracy: 0.9925
# Epoch 00034: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0199 - accuracy: 0.9926 - val_loss: 0.0301 - val_accuracy: 0.9900
# Epoch 35/50
# 254/262 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9947
# Epoch 00035: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0128 - accuracy: 0.9946 - val_loss: 0.0381 - val_accuracy: 0.9875
# Epoch 36/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0193 - accuracy: 0.9932
# Epoch 00036: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0191 - accuracy: 0.9932 - val_loss: 0.0348 - val_accuracy: 0.9883
# Epoch 37/50
# 250/262 [===========================>..] - ETA: 0s - loss: 0.0165 - accuracy: 0.9948
# Epoch 00037: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.0523 - val_accuracy: 0.9850
# Epoch 38/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.0183 - accuracy: 0.9951
# Epoch 00038: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0185 - accuracy: 0.9946 - val_loss: 0.0429 - val_accuracy: 0.9875
# Epoch 39/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.0184 - accuracy: 0.9941
# Epoch 00039: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.0347 - val_accuracy: 0.9883
# Epoch 40/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0171 - accuracy: 0.9946
# Epoch 00040: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.0599 - val_accuracy: 0.9817
# Epoch 41/50
# 258/262 [============================>.] - ETA: 0s - loss: 0.0154 - accuracy: 0.9945
# Epoch 00041: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.1191 - val_accuracy: 0.9642
# Epoch 42/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0151 - accuracy: 0.9949
# Epoch 00042: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.0367 - val_accuracy: 0.9892
# Epoch 43/50
# 254/262 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 0.9954
# Epoch 00043: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0449 - val_accuracy: 0.9875
# Epoch 44/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0133 - accuracy: 0.9953
# Epoch 00044: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0138 - accuracy: 0.9953 - val_loss: 0.0376 - val_accuracy: 0.9867
# Epoch 45/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.0155 - accuracy: 0.9951
# Epoch 00045: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0415 - val_accuracy: 0.9875
# Epoch 46/50
# 252/262 [===========================>..] - ETA: 0s - loss: 0.0137 - accuracy: 0.9951
# Epoch 00046: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.0309 - val_accuracy: 0.9900
# Epoch 47/50
# 253/262 [===========================>..] - ETA: 0s - loss: 0.0130 - accuracy: 0.9956
# Epoch 00047: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 1s 4ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.0459 - val_accuracy: 0.9892
# Epoch 48/50
#  85/262 [========>.....................] - ETA: 0s - loss: 0.0316 - accuracy: 0.9931
# Epoch 00048: val_accuracy did not improve from 0.99333
#  86/262 [========>.....................] - 0s 6ms/step - loss: 0.0316 - accuracy: 0.9931 - val_loss: 0.0737 - val_accuracy: 0.9783

# %% [markdown]
# # Plotting Loss and Accuracy
#
# The loss and accuracy for the training and validation datasets is plotted using the *show_final_history* function

# %%
show_final_history(history)

# %% [markdown]
# # Confusion Matrix for Validation dataset
#
# The confusion matrix

# %%
val_pred = model.predict(val_images)
val_pred = np.argmax(val_pred,axis=1)
val_pred.shape
# Out:
# (1200,)

# %%
val_actual = np.argmax(val_labels,axis=1)

cnf_mat = confusion_matrix(val_actual, val_pred)
np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cnf_mat,classes=class_names)
plt.grid(None)
plt.show();

# %% [markdown]
# ### With Augmentation:
#
# * Precision:
#     - *no-ship* : 0.942
#     - *ship* : 0.989
#
#
# * Recall:
#     - *no-ship* : 0.99
#     - *ship* : 0.94
#
# ### With class weights
#
# * Precision:
#     - *no-ship* : 1.00
#     - *ship* : 0.99
#
#
# * Recall:
#     - *no-ship* : 0.99
#     - *ship* : 1.00

# %% [markdown]
# # Confusion Matrix for Testing Dataset

# %%
test_pred = model.predict(test_images)
test_pred = np.argmax(test_pred,axis=1)
test_pred.shape
# Out:
# (600,)

# %%
test_actual = np.argmax(test_labels,axis=1)

cnf_mat_test = confusion_matrix(test_actual, test_pred)
np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cnf_mat_test,classes=class_names)
plt.grid(None)
plt.show()

# %% [markdown]
# # Checking the model

# %%
rnd_idx = random.sample(range(0,400),10)

class_labels = {i:class_name for (class_name,i) in class_name_labels.items()}
class_labels

# fig, ax = plt.subplots(2,5,figsize=(5,5))

for i,idx in enumerate(rnd_idx):
    
    plt.imshow(test_images[idx])
    plt.title("Actual: {}\nPredicted: {}".format(class_labels[test_actual[idx]],class_labels[test_pred[idx]]))
    plt.grid(None)
    plt.show()
    pass

# %% [markdown]
# **Saving the model**

# %%
model.save("ship-model.h5")
